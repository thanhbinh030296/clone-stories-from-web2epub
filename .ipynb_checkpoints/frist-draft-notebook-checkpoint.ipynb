# %%
import requests
#This will not run on online IDE
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
story_url = "https://truyentiki.com/dan-gian-quy-nghe-that-luc.46624/"
chapter_url = "https://truyentiki.com/dan-gian-quy-nghe-that-luc.46624/chuong-1179/"
chapter_pattern_url = "https://truyentiki.com/dan-gian-quy-nghe-that-luc.46624/chuong-"

# %%
from selenium import webdriver

url = "http://legendas.tv/busca/walking%20dead%20s03e02"
browser = webdriver.PhantomJS(executable_path=r"E:\Project\Python\phantomjs-2.1.1-windows\phantomjs-2.1.1-windows\bin")
browser.get(url)
html = browser.page_source

soup = BeautifulSoup(html, 'lxml')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 4
#       1 from selenium import webdriver
#       3 url = "http://legendas.tv/busca/walking%20dead%20s03e02"
# ----> 4 browser = webdriver.PhantomJS(executable_path=r"E:\Project\Python\phantomjs-2.1.1-windows\phantomjs-2.1.1-windows\bin")
#       5 browser.get(url)
#       6 html = browser.page_source
#
# AttributeError: module 'selenium.webdriver' has no attribute 'PhantomJS'

# %%
html

# %%
soup = BeautifulSoup(html, features="html.parser") # If this line causes an error, run 'pip install html5lib' or install html5lib
print(soup.prettify())
# Out:
# <!DOCTYPE html PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.0//EN" "http://www.wapforum.org/DTD/xhtml-mobile10.dtd">
# <html class="vocabbi_document" xml:lang="vi" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Dân Gian Quỷ Nghe Thật Lục : thứ 1179 chương  có lẽ ta có thể cho ngươi đáp án（ hết trọn bộ）
#   </title>
#   <meta content="width=device-width, initial-scale=1, minimum-scale=1.0, maximum-scale=1.7, user-scalable=yes" name="viewport"/>
#   <meta content="index, follow" name="robots"/>
#   <meta content="index,follow" name="Googlebot"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <link href="/a/css/bt.min.css?1" rel="stylesheet"/>
#   <link href="/a/css/mstyle.css?24" rel="stylesheet"/>
#   <script src="/a/js/jquery.min.1.12.0.js">
#   </script>
#   <script src="/a/js/lscache.min.js">
#   </script>
#   <script src="/a/js/iscript.js?t=1">
#   </script>
# ...

# %%
soup.find_all('center', attrs = {'id':'chapter_title'})
# Out:
# [<center id="chapter_title">1179. thứ 1179 chương  có lẽ ta có thể cho ngươi đáp án（ hết trọn bộ）</center>]

# %%
soup.find_all('center', attrs = {'id':'chapter_title'})[0].text
# Out:
# '1179. thứ 1179 chương  có lẽ ta có thể cho ngươi đáp án（ hết trọn bộ）'

# %%
soup.center
# Out:
# <center><form action="/index.php" class="btn-group" method="get"><a class="btn btn-success" href="/dan-gian-quy-nghe-that-luc.46624/chuong-1178/" id="prev_chap" title="Chương 1178"><span class="fa fa-chevron-circle-left"></span> Trước</a><input name="redirect" style="display:none" value="chapter"><input name="str_id" style="display:none" value="46624"/><input class="form-control" name="chapter_index" style="float: left; width: 60px; padding: 6px; text-align:center" value="1179"/><span style="float: left;line-height: 34px;font-size: 20px;font-weight: bold;margin-right:10px">/1179</span><button class="btn btn-success" type="submit">GO</button><a class="btn btn-default" disabled="" href="#" id="next_chap" title="">Sau <span class="fa fa-chevron-circle-right"></span></a></input></form></center>

# %%
soup.find_all("div", attrs={"id":"chapter_text"})[0]
# Out:
# <div id="chapter_text"><br/><br/>Đang tải nội dung chương ...."</div>
